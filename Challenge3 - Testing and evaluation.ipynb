# %% [markdown]
# ## **Testing and evaluation**

# %% [markdown]
# Importing vertexai generative model package

# %%
from vertexai import init
from vertexai.preview.generative_models import GenerativeModel

# %% [markdown]
# Initializing VertexAI

# %%
init(project="qwiklabs-gcp-00-1c0ebb19fb7c", location="global")

# %% [markdown]
# Function 1: category classifier

# %%
def classify_question_with_gemini(question: str) -> str:
    categories = ["Employment", "General Information", "Emergency Services", "Tax Related"]
    prompt = (
        "You are a good content classifier tool.\n"
        "Classify the user's question into one of the following categories:\n"
        f"{', '.join(categories)}.\n\n"
        "If the question doesn't come under any category, just say: No relevant category.\n"
        f"Return only the matched category name exactly as listed above (i.e., {', '.join(categories)}).\n"
        "Do not enclose the result/category with single or double quotes.\n\n"
        f"Question: {question}\n"
        "Category:"
    )

    gemini_model = GenerativeModel("gemini-2.5-pro-preview-06-05")
    response = gemini_model.generate_content(prompt)
    result = response.text.strip()

    if result in categories:
        return result
    else:
        return "No relevant category"

# %%
classify_question_with_gemini("Best tourist places?")
# Out:
# 'General Information'

# %% [markdown]
# Installing pytest library

# %%
# !pip install -q google-cloud-aiplatform pytest

# %% [markdown]
# Test case for category classifier function

# %%
import pytest

def test_classify_question(testcases):
  for test in testcases:
    result = classify_question_with_gemini(test['query'])
    print("Result:", result)

    assert result is not None, "Function returned None"
    assert result.strip().lower() == test['category'].lower(), "Classification did not match"
    print(f"Tax test case passed for category - {test['category']}")

# %%
testcases=[
    {'query':"accident helpline number",'category':"Emergency Services"},
    {'query':"Best tourist places",'category':"General Information"},
    {'query':"How to apply for a job?",'category':"Employment"},
    {'query':"What are the steps to file my income tax?",'category':"Tax Related"}
    ]

# %%
test_classify_question(testcases)
# Out:
# Result: Emergency Services
# Tax test case passed for category - Emergency Services
# Result: General Information
# Tax test case passed for category - General Information
# Result: Employment
# Tax test case passed for category - Employment
# Result: Tax Related
# Tax test case passed for category - Tax Related

# %% [markdown]
# Function2: Generate social media posts

# %%
def generate_announcement_post(event: str) -> str:
    prompt = (
        "You are a professional social media content.\n"
        "Write a short, friendly social media post for the following government announcement:\n"
        f"{event}\n\n"
        "Make it suitable for Twitter or Facebook."
    )

    gemini_model = GenerativeModel("gemini-2.5-pro-preview-06-05")
    response = gemini_model.generate_content(prompt)
    return response.text

# %%
generate_announcement_post("New year wishes")
# Out:
# 'Of course! Here are a few options, from casual to slightly more formal, all designed to be short, friendly, and engaging.\n\n### Option 1: (Warm & Casual)\n\nHappy New Year! 🎉 Wishing you and your family a year filled with joy, health, and happiness. We\'re excited for all the great things to come for our community in 2024. Cheers to a fresh start!\n\n#HappyNewYear #NewYear2024 #[YourCity/StateName]\n\n---\n\n### Option 2: (Community-Focused)\n\nWishing a very Happy New Year to everyone in our wonderful community! May the coming year bring new opportunities, success, and prosperity for all. We look forward to another year of serving you and building a better future, together.\n\n#HappyNewYear #Community #LookingForward\n\n---\n\n### Option 3: (Short & Sweet for Twitter)\n\nHappy New Year! 🎆 From all of us here, we wish you a safe, healthy, and prosperous 2024. Let\'s make it a great one!\n\n#NewYearWishes #2024\n\n---\n\n**Pro-Tips for the Post:**\n\n*   **Add a Visual:** Include a high-quality image or a short video. Great options include:\n    *   Fireworks over a local landmark.\n    *   A festive graphic with your department\'s logo.\n    *   A short, silent video montage of community highlights from the past year.\n*   **Schedule in Advance:** Use your platform\'s scheduling tool to have this post go live right at midnight on New Year\'s Eve or first thing in the morning on New Year\'s Day.\n*   **Engage with Replies:** If people comment with their own new year wishes, be sure to "like" or reply to a few to foster a sense of community.'

# %% [markdown]
# function to evaluate the relevance of generate social media post result

# %%
def evaluate_post_relevance_with_gemini(input_text: str, generated_post: str) -> str:
    model = GenerativeModel("gemini-2.5-pro-preview-06-05")

    prompt = f"""
    You are an AI assistant helping to check if a social media post is relevant to the original announcement.

    Original Announcement:
    "{input_text}"

    Generated Post:
    "{generated_post}"

    Is the generated post relevant to the original announcement?
    Reply only with "Yes" or "No".
    """

    response = model.generate_content(prompt)
    return response.text.strip()

# %% [markdown]
# Pytest for social media post generator

# %%
import pytest

def test_announcement_post_relevance_with_gemini():
    input_text = "All schools will be closed due to snow on Monday."
    post = generate_announcement_post(input_text)

    relevance = evaluate_post_relevance_with_gemini(input_text, post)

    print("Generated Post:\n", post)
    print("Gemini Relevance Check:", relevance)

    assert relevance.lower() == "yes", "The post is not relevant"

# %%
test_announcement_post_relevance_with_gemini()
# Out:
# Generated Post:
#  Of course! Here are a few options, from the most straightforward and friendly to a slightly more playful one.
#
# ### Option 1 (Friendly & Direct - Great for Facebook/Twitter)
#
# **Heads Up, Parents & Students!** ❄️
#
# Due to the heavy snow, all [Your City/County] schools will be closed on Monday, [Date].
#
# Please stay safe and warm out there! We'll share any further updates right here.
#
# #SnowDay #SchoolClosure #[YourCityName]
#
# ---
#
# ### Option 2 (Safety-Focused - A bit more formal)
#
# **Important Weather Announcement:**
#
# For the safety of our students and staff, all schools will be closed on Monday, [Date], due to the snow.
#
# Stay home if you can and please be careful on the roads. For more information, visit our website: [Link]
#
# #SafetyFirst #WeatherUpdate #[YourCounty]
#
# ---
#
# ### Option 3 (Playful & Fun - Great for a school district's page)
#
# **Get the hot chocolate ready!** ☕️☃️
#
# It's official: Monday is a SNOW DAY! All our schools will be closed due to the winter weather.
#
# Enjoy the extra day, be safe, and we'll see everyone on Tuesday!
#
# #SnowDay! #NoSchoolMonday #[YourDistrictName]
# Gemini Relevance Check: Yes

# %% [markdown]
# # **Google Evaluation API**

# %% [markdown]
# Test dataset for evaluation

# %%
test_dataset = [
    {"query": "How do I apply for a government job?", "category": "Employment"},
    {"query": "What is the income tax filing deadline?", "category": "Tax Related"},
    {"query": "Is there a helpline for ambulance services?", "category": "Emergency Services"},
    {"query": "What are the best places to visit in summer?", "category": "General Information"},
    {"query": "How do I upload my resume to the job portal?", "category": "Employment"},
    {"query": "Where can I pay my property tax?", "category": "Tax Related"},
    {"query": "Fire emergency contact number?", "category": "Emergency Services"},
    {"query": "Where can I find tourist guides for my city?", "category": "General Information"},
    {"query": "Steps to register for unemployment benefits?", "category": "Employment"},
    {"query": "Do we have school tomorrow?", "category": "General Information"},
    {"query": "Police station near me?", "category": "Emergency Services"},
    {"query": "I want to know about tax rebates.", "category": "Tax Related"},
    {"query": "What time does the post office open?", "category": "General Information"},
    {"query": "Can I file my taxes online?", "category": "Tax Related"},
    {"query": "Help! There’s a gas leak in my house!", "category": "Emergency Services"},
]

# %%
import pandas as pd
from vertexai.preview.evaluation import EvalTask, MetricPromptTemplateExamples

# %% [markdown]
# Configuring evaluation dataset

# %%
categories = ["Employment", "General Information", "Emergency Services", "Tax Related"]
eval_dataset = pd.DataFrame([
    {
        "instruction": "You are a good content classifier tool.\n"
                        "Classify the user's question into one of the following categories:\n"
                        f"{', '.join(categories)}.\n\n"
                        "If the question doesn't come under any category, just say: No relevant category.\n"
                        f"Return only the matched category name exactly as listed above (i.e., {', '.join(categories)}).\n"
                        "Do not enclose the result/category with single or double quotes.\n\n",
        "context": f"category: {test_data['query']}",
        "response": test_data["category"],
    } for test_data in test_dataset
])

# %%
import datetime
run_ts = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
eval_task = EvalTask(
    dataset=eval_dataset,
    metrics=[
        MetricPromptTemplateExamples.Pointwise.INSTRUCTION_FOLLOWING,
        MetricPromptTemplateExamples.Pointwise.GROUNDEDNESS,
        MetricPromptTemplateExamples.Pointwise.VERBOSITY,
        MetricPromptTemplateExamples.Pointwise.SUMMARIZATION_QUALITY
    ],
    experiment=f"classify-question-with-gemini-{run_ts}"
)

# %%
init(project="qwiklabs-gcp-00-1c0ebb19fb7c", location="us-central1")

# %% [markdown]
# Running evaluation task

# %%
prompt_template = (
    "Instruction: {instruction}. query: {context}. category: {response}"
)
result = eval_task.evaluate(
      prompt_template=prompt_template,
      experiment_run_name=f"classify-question-with-gemini-{run_ts}"
)
evaluation_results = []
evaluation_results.append(result)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-42c3419d-f437-44f6-9f41-75bf73e6122c" href="#view-view-vertex-resource-42c3419d-f437-44f6-9f41-75bf73e6122c">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-42c3419d-f437-44f6-9f41-75bf73e6122c');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/classify-question-with-gemini-20250616-112447/runs?project=qwiklabs-gcp-00-1c0ebb19fb7c');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/classify-question-with-gemini-20250616-112447/runs?project=qwiklabs-gcp-00-1c0ebb19fb7c', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-c6d714dd-53a4-44b6-9b01-3e8a59eb7719" href="#view-view-vertex-resource-c6d714dd-53a4-44b6-9b01-3e8a59eb7719">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-c6d714dd-53a4-44b6-9b01-3e8a59eb7719');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/classify-question-with-gemini-20250616-112447/runs/classify-question-with-gemini-20250616-112447-classify-question-with-gemini-20250616-112447?project=qwiklabs-gcp-00-1c0ebb19fb7c');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/classify-question-with-gemini-20250616-112447/runs/classify-question-with-gemini-20250616-112447-classify-question-with-gemini-20250616-112447?project=qwiklabs-gcp-00-1c0ebb19fb7c', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.preview.evaluation.eval_task:Logging Eval experiment evaluation metadata: {'prompt_template': 'Instruction: {instruction}. query: {context}. category: {response}'}
# INFO:vertexai.preview.evaluation._evaluation:Assembling prompts from the `prompt_template`. The `prompt` column in the `EvalResult.metrics_table` has the assembled prompts used for model response generation.
# INFO:vertexai.preview.evaluation._evaluation:Computing metrics with a total of 60 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 60/60 [00:06<00:00,  9.13it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 60 metric requests are successfully computed.
# INFO:vertexai.preview.evaluation._evaluation:Evaluation Took:6.581563384002948 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-271d2fa9-8aa6-4324-92b6-2feaf955e434" href="#view-view-vertex-resource-271d2fa9-8aa6-4324-92b6-2feaf955e434">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-271d2fa9-8aa6-4324-92b6-2feaf955e434');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation');
#               } else {
#                 window.open('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %% [markdown]
# Result comparison

# %%
from vertexai.preview.evaluation import notebook_utils
notebook_utils.display_eval_result(eval_result=result)
# Out:
# ### Summary Metrics
#    row_count  instruction_following/mean  instruction_following/std  \
# 0       15.0                         5.0                        0.0
#
#    groundedness/mean  groundedness/std  verbosity/mean  verbosity/std  \
# 0                1.0               0.0             0.0            0.0
#
#    summarization_quality/mean  summarization_quality/std
# 0                         5.0                        0.0
# ### Row-based Metrics
#                                           instruction  \
# 0   You are a good content classifier tool.\nClass...
# 1   You are a good content classifier tool.\nClass...
# 2   You are a good content classifier tool.\nClass...
# 3   You are a good content classifier tool.\nClass...
# 4   You are a good content classifier tool.\nClass...
# 5   You are a good content classifier tool.\nClass...
# 6   You are a good content classifier tool.\nClass...
# 7   You are a good content classifier tool.\nClass...
# 8   You are a good content classifier tool.\nClass...
# 9   You are a good content classifier tool.\nClass...
# 10  You are a good content classifier tool.\nClass...
# 11  You are a good content classifier tool.\nClass...
# 12  You are a good content classifier tool.\nClass...
# 13  You are a good content classifier tool.\nClass...
# 14  You are a good content classifier tool.\nClass...
#
#                                               context             response  \
# 0      category: How do I apply for a government job?           Employment
# 1   category: What is the income tax filing deadline?          Tax Related
# 2   category: Is there a helpline for ambulance se...   Emergency Services
# 3   category: What are the best places to visit in...  General Information
# 4   category: How do I upload my resume to the job...           Employment
# 5          category: Where can I pay my property tax?          Tax Related
# 6            category: Fire emergency contact number?   Emergency Services
# 7   category: Where can I find tourist guides for ...  General Information
# 8   category: Steps to register for unemployment b...           Employment
# 9               category: Do we have school tomorrow?  General Information
# 10                  category: Police station near me?   Emergency Services
# 11        category: I want to know about tax rebates.          Tax Related
# 12     category: What time does the post office open?  General Information
# 13              category: Can I file my taxes online?          Tax Related
# 14    category: Help! There’s a gas leak in my house!   Emergency Services
#
#                                                prompt  \
# 0   Instruction: You are a good content classifier...
# 1   Instruction: You are a good content classifier...
# 2   Instruction: You are a good content classifier...
# 3   Instruction: You are a good content classifier...
# 4   Instruction: You are a good content classifier...
# 5   Instruction: You are a good content classifier...
# 6   Instruction: You are a good content classifier...
# 7   Instruction: You are a good content classifier...
# 8   Instruction: You are a good content classifier...
# 9   Instruction: You are a good content classifier...
# 10  Instruction: You are a good content classifier...
# 11  Instruction: You are a good content classifier...
# 12  Instruction: You are a good content classifier...
# 13  Instruction: You are a good content classifier...
# 14  Instruction: You are a good content classifier...
#
#                     instruction_following/explanation  \
# 0   The response accurately classifies the user's ...
# 1   The response correctly classified the user's q...
# 2   The model correctly classifies the user query ...
# 3   The response follows all the instructions incl...
# 4   The response correctly identifies the category...
# 5   The response correctly classifies the query in...
# 6   The response correctly classified the query in...
# 7   The response completely fulfills the instructi...
# 8   The model accurately classifies the user quest...
# 9   The response correctly classifies the user que...
# 10  The response adheres to all instructions, accu...
# 11  The response correctly classifies the user's q...
# 12  The response successfully classified the user'...
# 13  The response accurately classifies the user's ...
# 14  The response accurately classified the user's ...
#
#     instruction_following/score  \
# 0                           5.0
# 1                           5.0
# 2                           5.0
# 3                           5.0
# 4                           5.0
# 5                           5.0
# 6                           5.0
# 7                           5.0
# 8                           5.0
# 9                           5.0
# 10                          5.0
# 11                          5.0
# 12                          5.0
# 13                          5.0
# 14                          5.0
#
#                              groundedness/explanation  groundedness/score  \
# 0   The response 'Employment' is directly attribut...                 1.0
# 1   The AI model correctly classifies the user's q...                 1.0
# 2   The response 'Emergency Services' is directly ...                 1.0
# 3   The response, 'General Information', accuratel...                 1.0
# 4   The AI's response is fully grounded in the use...                 1.0
# 5   The response 'Tax Related' is fully grounded i...                 1.0
# 6   The response is fully grounded as it only uses...                 1.0
# 7   The response correctly identifies the category...                 1.0
# 8   The response is fully grounded as it accuratel...                 1.0
# 9   The response correctly identified the user's q...                 1.0
# 10  The response correctly identifies the category...                 1.0
# 11  The response is fully grounded as it returns t...                 1.0
# 12  The response correctly identifies the category...                 1.0
# 13  The response 'Tax Related' is directly attribu...                 1.0
# 14  The response 'Emergency Services' is directly ...                 1.0
#
#                                 verbosity/explanation  verbosity/score  \
# 0   The response is perfectly concise, providing a...              0.0
# 1   The response is perfectly concise, providing t...              0.0
# 2   The response is perfectly concise, providing a...              0.0
# 3   The response is perfectly concise, providing a...              0.0
# 4   The response is perfectly concise and provides...              0.0
# 5   The response is perfectly concise, providing a...              0.0
# 6   The response is appropriately concise as it di...              0.0
# 7   The response is perfectly concise as it return...              0.0
# 8   The response is perfectly concise, providing a...              0.0
# 9   The response is perfectly concise, providing a...              0.0
# 10  The response is perfectly concise, providing t...              0.0
# 11  The response is perfectly concise, providing a...              0.0
# 12  The response is perfectly concise, providing a...              0.0
# 13  The response is perfectly concise as it provid...              0.0
# 14  The response is perfectly concise and provides...              0.0
#
#                     summarization_quality/explanation  \
# 0   The model correctly classified the query into ...
# 1   The response correctly identifies the category...
# 2   The response correctly classifies the query in...
# 3   The response correctly classifies the user's q...
# 4   The response accurately classifies the user's ...
# 5   The model correctly classified the query into ...
# 6   The response correctly classifies the user que...
# 7   The response correctly classifies the query in...
# 8   The response follows all instructions, correct...
# 9   The response correctly classifies the user's q...
# 10  The model correctly classifies the user query ...
# 11  The response correctly classifies the user's q...
# 12  The response correctly classifies the query in...
# 13  The response correctly identifies the category...
# 14  The response accurately classifies the user's ...
#
#     summarization_quality/score
# 0                           5.0
# 1                           5.0
# 2                           5.0
# 3                           5.0
# 4                           5.0
# 5                           5.0
# 6                           5.0
# 7                           5.0
# 8                           5.0
# 9                           5.0
# 10                          5.0
# 11                          5.0
# 12                          5.0
# 13                          5.0
# 14                          5.0
